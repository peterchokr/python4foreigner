# %% [markdown]
# # Python Coding Test
#
# **Total Questions**: 5 (3 Beginner + 2 Intermediate)
# **Total Points**: 10
# **Time Limit**: 2 hours
# There are five questions. You will be graded on the number of questions you solve. Raise your hand if you wish to be graded.
#
# ### Instructions
# Write Python code to solve each problem. Use operators, conditional statements, loops, and input/output functions learned in class.
#
# This is an open-book exam. You can use course materials, Google searches, and other resources. However, you must code yourself. Using AI tools like ChatGPT or Gemini to code is considered cheating.

# %% [markdown]
# ---
# # BEGINNER LEVEL (3 Questions - 2 points each)
#
# ## Question 1: Online Shopping Discount Calculator (2 points)
#
# **Topics**: Arithmetic operators, Comparison operators, Input/Output
#
# ### Problem Description
# An online store offers discounts based on purchase amount:
# - Purchase less than $50: No discount
# - Purchase $50-$99: 10% discount
# - Purchase $100 or more: 20% discount
#
# Write a program that:
# 1. Asks the customer for the original price of their purchase
# 2. Calculates the discount amount based on the price
# 3. Calculates the final price (original - discount)
# 4. Displays all prices clearly
#
# ### Example Output
# ```
# Enter original purchase price: $85
# Original price: $85.00
# Discount applied: 10%
# Discount amount: $8.50
# Final price: $76.50
# ```
#
# ### Requirements
# - Input the original price using `input()`
# - Use conditional statements (if/elif/else)
# - Use arithmetic operators for discount calculation
# - Display results with proper formatting

# %%
# Question 1: Online Shopping Discount Calculator
# Write your code below

# %% [markdown]
# ---
# ## Question 2: Temperature Clothing Advisor (2 points)
#
# **Topics**: Input/Output, Comparison operators, Conditional statements
#
# ### Problem Description
# Create a clothing recommendation program based on temperature (in Celsius):
#
# | Temperature Range | Recommendation |
# |------------------|------------------|
# | 25°C and above | Wear light clothes and sunglasses |
# | 15-24°C | Wear a light jacket |
# | 5-14°C | Wear a warm coat and scarf |
# | Below 5°C | Wear heavy winter clothes and gloves |
#
# Write a program that:
# 1. Asks the user for the current temperature
# 2. Determines the appropriate clothing recommendation
# 3. Displays the temperature and recommendation
#
# ### Example Output
# ```
# Enter current temperature (°C): 12
# Current temperature: 12°C
# Recommendation: Wear a warm coat and scarf
# ```
#
# ### Requirements
# - Use `input()` to get temperature
# - Use multiple conditional statements (if/elif/else)
# - Convert input to float
# - Display clear recommendations

# %%
# Question 2: Temperature Clothing Advisor
# Write your code below

# %% [markdown]
# ---
# ## Question 3: Classroom Grade Summary (2 points)
#
# **Topics**: Input/Output, Arithmetic operators, Loop (while)
#
# ### Problem Description
# Write a program to calculate class grade statistics. The program collects exam scores from multiple students and computes summary statistics.
#
# The program should:
# 1. Use a while loop to collect grades from multiple students
# 2. Accept grades until the user enters -1 (sentinel value)
# 3. Calculate the total points of all students
# 4. Calculate the average grade
# 5. Count the total number of students
# 6. Display the summary statistics
#
# ### Example Output
# ```
# === Classroom Grade Summary ===
# Enter grade (or -1 to finish): 85
# Enter grade (or -1 to finish): 90
# Enter grade (or -1 to finish): 78
# Enter grade (or -1 to finish): 92
# Enter grade (or -1 to finish): -1
#
# Summary:
# Total students: 4
# Total points: 345
# Average grade: 86.25
# ```
#
# ### Requirements
# - Use a while loop to repeatedly accept grades
# - Use -1 as the sentinel value to stop input
# - Use arithmetic operators to calculate total and average
# - Use a counter variable to track the number of students
# - Use accumulator variable for the total points
# - Display results with proper formatting

# %%
# Question 3: Classroom Grade Summary
# Write your code below

# %% [markdown]
# ---
# # INTERMEDIATE LEVEL (2 Questions - 4 points each)
#
# ## Question 4: Student Grade and Scholarship Eligibility (4 points)
#
# **Topics**: Multiple comparison operators, Logical operators (AND), Conditional statements
#
# ### Problem Description
# A university awards scholarships based on:
# - **Grade Requirement**: Average score must be 80 or higher
# - **Attendance Requirement**: Must have 90% or higher attendance
# - **Financial Need**: Monthly family income must be less than $3,000
#
# Scholarship awards:
# - All three conditions met: $5,000 scholarship
# - Grade and Attendance met (not financial need): $2,500 scholarship
# - Any other condition met: $1,000 scholarship
# - No conditions met: No scholarship
#
# Write a program that:
# 1. Inputs the student's average score, attendance percentage, and family income
# 2. Checks all three requirements
# 3. Determines scholarship eligibility and amount
# 4. Displays the results with detailed information
#
# ### Example Output
# ```
# === Scholarship Eligibility Check ===
# Enter your average score: 85
# Enter your attendance percentage: 92
# Enter your family income (monthly): $2,500
#
# Results:
# Average score: 85 (PASS - meets requirement)
# Attendance: 92% (PASS - meets requirement)
# Family income: $2,500 (PASS - needs scholarship)
#
# Eligibility: YES
# Scholarship amount: $5,000
# Congratulations! You qualify for a full scholarship.
# ```
#
# ### Requirements
# - Use `input()` to get three values (score, attendance, income)
# - Convert inputs to appropriate data types (int or float)
# - Use logical operators (`and`) to combine multiple conditions
# - Use nested conditional statements (if/elif/else)
# - Display detailed results for each criterion
# - Show the final scholarship decision and amount

# %%
# Question 4: Student Grade and Scholarship Eligibility
# Write your code below

# %% [markdown]
# ---
# ## Question 5: Online Shopping Shipping Fee Calculator (4 points)
#
# **Topics**: Multiple arithmetic operators, Comparison operators, Conditional statements
#
# ### Problem Description
# An online shopping website calculates shipping fees based on these rules:
#
# **Base Shipping Fee (by weight)**:
# - Less than 1 kg: $5
# - 1 kg to 5 kg: $8
# - More than 5 kg: $12
#
# **Express Shipping Surcharge**:
# - Standard (Normal speed): No surcharge
# - Express: Add 50% to base fee
# - Overnight: Add 100% to base fee
#
# **Member Discount**:
# - Non-member: No discount
# - Regular member: 10% discount on total shipping fee
# - Premium member: 20% discount on total shipping fee
#
# Write a program that:
# 1. Inputs the order total, package weight, shipping type, and membership status
# 2. Calculates the base shipping fee based on weight
# 3. Applies shipping type surcharge if applicable
# 4. Applies member discount if applicable
# 5. Displays a clear breakdown of all calculations
# 6. Shows the final shipping fee
#
# ### Example Output 1
# ```
# === Shipping Fee Calculator ===
# Enter order total: $150
# Enter package weight (kg): 3
# Enter shipping type (standard/express/overnight): express
# Enter membership status (none/regular/premium): regular
#
# Calculation:
# Base shipping fee (1-5 kg): $8.00
# Express surcharge (50%): +$4.00
# Subtotal: $12.00
# Regular member discount (10%): -$1.20
#
# Final Shipping Fee: $10.80
# ```
#
# ### Requirements
# - Input four values: order total, weight, shipping type, membership
# - Use comparison operators for weight ranges
# - Use nested conditional statements
# - Calculate base fee, surcharge, and discount step-by-step
# - Clearly show each calculation step
# - Display the final shipping fee
# - Handle all shipping types and membership levels

# %%
# Question 5: Online Shopping Shipping Fee Calculator
# Write your code below

# %% [markdown]
# ---
# # 🌟 Good luck with your coding test!
# **Remember**: Practice makes perfect! Show your step-by-step thinking in your code.
